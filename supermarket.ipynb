# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r'C:\Users\Arcite\Downloads\supermarket_sales - Sheet1.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
print(df.describe())
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['Date'])

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['day'] = (df['date']).dt.day
df['month'] = (df['date']).dt.month
df['year'] = (df['date']).dt.year

# %%
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_7204\2145562215.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
df['Hour'] = (df['Time']).dt.hour

# %%
df['Hour'].nunique()
# Out:
# 11

# %%
sns.set(style="darkgrid")       
genderCount = sns.countplot(x="Gender", data =df,palette=['#1f77b4','#ff7f0e']).set_title("Gender_Count")
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_7204\716253509.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   genderCount = sns.countplot(x="Gender", data =df,palette=['#1f77b4','#ff7f0e']).set_title("Gender_Count")

# %%
sns.boxplot(x="Branch", y = "Rating" ,data =df,palette=['#1f77b4','#ff7f0e','#6B5B95']).set_title("Ratings by Branch")
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_7204\1559175074.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Branch", y = "Rating" ,data =df,palette=['#1f77b4','#ff7f0e','#6B5B95']).set_title("Ratings by Branch")
# Text(0.5, 1.0, 'Ratings by Branch')

# %%
sns.countplot(y = 'Product line', data=df, order = df['Product line'].value_counts().index )
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %% [markdown]
# Payment Channel

# %%
sns.countplot(x="Payment", data =df,palette=['#1f77b4','#ff7f0e','#6B5B95']).set_title("Payment Channel")
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_10864\1642812143.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Payment", data =df,palette=['#1f77b4','#ff7f0e','#6B5B95']).set_title("Payment Channel")
# Text(0.5, 1.0, 'Payment Channel')

# %% [markdown]
# Most of the customers pay through the Ewallet and Cash Payment while under 40 percent of them pay with their credit card. We would also like to see this payment type distribution across all the branches

# %%
sns.countplot(x="Payment", hue = "Branch", data =df).set_title("Payment Channel by Branch")
# Out:
# Text(0.5, 1.0, 'Payment Channel by Branch')

# %% [markdown]
# Customer Analysis

# %%
df['Customer type'].nunique()
# Out:
# 2

# %%
 sns.countplot(x="Customer type", data =df,palette=['#1f77b4','#ff7f0e']).set_title("Customer Type")
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_10864\1001737305.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Customer type", data =df,palette=['#1f77b4','#ff7f0e']).set_title("Customer Type")
# Text(0.5, 1.0, 'Customer Type')

# %%
sns.countplot(x="Customer type", hue = "Branch", data =df).set_title("Customer Type by Branch")
# Out:
# Text(0.5, 1.0, 'Customer Type by Branch')

# %% [markdown]
# Does customer type influences the sales

# %%
df.groupby(['Customer type']).agg({'Total': 'sum'})
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305

# %%
sns.barplot(x="Customer type", y="Total", estimator = sum, palette=['#1f77b4','#ff7f0e'],data=df)
# Out:
# C:\Users\Arcite\AppData\Local\Temp\ipykernel_10864\715717003.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Customer type", y="Total", estimator = sum, palette=['#1f77b4','#ff7f0e'],data=df)
# <Axes: xlabel='Customer type', ylabel='Total'>
