# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Arcite\Downloads\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].describe())
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df1=df.drop(['Id'],axis=1)
df1
df2=df1.drop('Species',axis=1)

# %%
df1.groupby("Species").mean(numeric_only=True)
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %% [markdown]
# Sepal Width of Setosa(3.42) and virginica(2.97) flowers do not have the same average.
# sepal Length of Versicolor(5.94) and virginica(6.59) flowers do not have the same average and Virginica has the longer sepal length on average.

# %%
df.groupby("Species")['SepalWidthCm'].mean().plot(kind='bar',color='green')
plt.title('Average sepal width')
plt.show()

# %%
df.groupby("Species")['SepalLengthCm'].mean().plot(kind='bar',color='grey')
plt.title('Average sepal length')
plt.show()

# %%
df.groupby("Species")['PetalLengthCm'].mean().plot(kind='bar',color='pink')
plt.title('Average petal length')
plt.show()

# %%
df.groupby("Species")['PetalWidthCm'].mean().plot(kind='bar',color='yellow')
plt.title('Average petal width')
plt.show()

# %%
df1.groupby("Species").max(numeric_only=True)
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa                5.8           4.4            1.9           0.6
# Iris-versicolor            7.0           3.4            5.1           1.8
# Iris-virginica             7.9           3.8            6.9           2.5

# %%
df1.groupby("Species").min(numeric_only=True)
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa                4.3           2.3            1.0           0.1
# Iris-versicolor            4.9           2.0            3.0           1.0
# Iris-virginica             4.9           2.2            4.5           1.4

# %%
df1.sort_values(by='PetalLengthCm')
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 22             4.6           3.6            1.0           0.2     Iris-setosa
# 13             4.3           3.0            1.1           0.1     Iris-setosa
# 14             5.8           4.0            1.2           0.2     Iris-setosa
# 35             5.0           3.2            1.2           0.2     Iris-setosa
# 16             5.4           3.9            1.3           0.4     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 131            7.9           3.8            6.4           2.0  Iris-virginica
# 105            7.6           3.0            6.6           2.1  Iris-virginica
# 117            7.7           3.8            6.7           2.2  Iris-virginica
# 122            7.7           2.8            6.7           2.0  Iris-virginica
# 118            7.7           2.6            6.9           2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# Here the setosa has smaller measurements while virginica has higher.

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df1["Species_code"]=df1['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
print(df1[['Species',"Species_code"]])
# Out:
#             Species  Species_code
# 0       Iris-setosa             0
# 1       Iris-setosa             0
# 2       Iris-setosa             0
# 3       Iris-setosa             0
# 4       Iris-setosa             0
# ..              ...           ...
# 145  Iris-virginica             2
# 146  Iris-virginica             2
# 147  Iris-virginica             2
# 148  Iris-virginica             2
# 149  Iris-virginica             2
#
# [150 rows x 2 columns]

# %%
df['SepalRatio']=df['SepalLengthCm']/df['SepalWidthCm']
df['PetalRatio']=df['PetalLengthCm']/df['PetalWidthCm']
print('\n--- Average Ratios by species---')
print(df.groupby("Species")[['SepalRatio','PetalRatio']].mean())
# Out:
# --- Average Ratios by species---
#                  SepalRatio  PetalRatio
# Species
# Iris-setosa        1.474578    7.078000
# Iris-versicolor    2.160402    3.242837
# Iris-virginica     2.230453    2.780662

# %%
v=df.groupby("Species")['SepalWidthCm'].var()
print("Highest variance in sepal width:",v.idxmax())
# Out:
# Highest variance in sepal width: Iris-setosa

# %%
print("Correlation between sepal length and petal Length:",df['SepalLengthCm'].corr(df['PetalLengthCm']))
# Out:
# Correlation between sepal length and petal Length: 0.8717541573048712

# %% [markdown]
# There is a strong relation between the sepal length and petal length.

# %%
plt.figure(figsize=(8,6))
plt.scatter(x='SepalLengthCm',y='PetalLengthCm',data=df)
plt.title('sepal length v/s petal length')
plt.show()

# %% [markdown]
# Sepal Lenght and Petal Length are strongly positively correlataed,means the sepal gets longer as well as the petal tends to get longer.
# This relationship holds across species,though the strength varies(Setosa has shorter petals regardless).

# %%
print("Correlation between sepal width and petal width:",df['SepalWidthCm'].corr(df['PetalWidthCm']))
# Out:
# Correlation between sepal width and petal width: -0.35654408961380574

# %% [markdown]
# There is a very weak relation between the sepal width and petal width.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.figure(figsize=(8,6))
plt.scatter(x='SepalWidthCm',y='PetalWidthCm',data=df)
plt.title('sepal width v/s petal width')
plt.show()

# %%
df.groupby("Species")['SepalWidthCm'].mean().plot(kind='bar',color='lightgreen')
plt.title('Average sepal width')
plt.show()

# %%
sns.pairplot(df1,hue='Species',diag_kind='kde')
plt.show()

# %% [markdown]
# Petal Length vs petal width:Almost perfect separation of species.
# Sepal length helps but has overlap between Versicolor and Virginica.
# Sepal width is not very discriminative(lots of overlaps).
# Setosa forms a completely distinct cluster.

# %%
sns.heatmap(df2.corr(),annot=True,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap of Iris Features')
plt.show()

# %%
from scipy import stats
setosa_petal=df[df['Species']=='setosa']['petal length (cm)']
versicolor_petal=df[df['Species']=='versicolor']['petal length (cm)']
t_statistic,p_value=ttest_ind(setosa_petal,versicolor_petal)
print(f"t-statistic: {t_statistic}")
print(f"P-value: {p_value}")
# Out:
# t-statistic: -39.492719391538095
# P-value: 5.404910513441677e-62

# %% [markdown]
# Since the p-value>=0.05 it fail to reject Ho(petal length of setosa=versicolor),that means there is no significant differnce.

# %%
s=df[df['Species']=='setosa']
plt.hist([s['sepal length (cm)'],s['sepal width (cm)'],s['petal length (cm)'],s['petal width (cm)']],bins=50,stacked=True,label=["Sepal length",'sepal width','petal length','Petal width'])
plt.xlabel("Values(Cm)")
plt.ylabel("Frequency")
plt.show()
